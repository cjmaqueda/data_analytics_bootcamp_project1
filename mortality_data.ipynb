# %%
#import dependencies
import pandas as pd
import numpy as np
import csv
# %matplotlib notebook

# %%
#read csv and turn into df
file = "mortality_data.csv"

# Read our Kickstarter data into pandas
mortality_data_df = pd.read_csv(file)
mortality_data_df.head(1)
# Out:
#         Location  FIPS            Category  Mortality Rate, 1980*  \
# 0  United States   NaN  Neonatal disorders                   9.18
#
#    Mortality Rate, 1980* (Min)  Mortality Rate, 1980* (Max)  \
# 0                         8.83                         9.93
#
#    Mortality Rate, 1985*  Mortality Rate, 1985* (Min)  \
# 0                   6.91                         6.73
#
#    Mortality Rate, 1985* (Max)  Mortality Rate, 1990*  \
# 0                         7.36                   6.09
#
#                       ...                       Mortality Rate, 2005* (Max)  \
# 0                     ...                                              4.55
#
#    Mortality Rate, 2010*  Mortality Rate, 2010* (Min)  \
# 0                   3.75                         3.43
#
#    Mortality Rate, 2010* (Max)  Mortality Rate, 2014*  \
# 0                         3.85                   3.32
#
#    Mortality Rate, 2014* (Min)  Mortality Rate, 2014* (Max)  \
# ...

# %%
mortality_data_df.describe()
# Out:
#                FIPS  Mortality Rate, 1980*  Mortality Rate, 1980* (Min)  \
# count  67053.000000           67074.000000                 67074.000000
# mean   29898.810836              51.671032                    47.379253
# std    15512.679073             112.480259                   105.565019
# min        1.000000               0.020000                     0.010000
# 25%    18101.000000               1.800000                     1.350000
# 50%    29125.000000              14.600000                    12.070000
# 75%    45055.000000              38.390000                    34.727500
# max    56045.000000             967.180000                   859.120000
#
#        Mortality Rate, 1980* (Max)  Mortality Rate, 1985*  \
# count                 67074.000000           67074.000000
# mean                     56.308657              49.866569
# std                     119.717786             105.974691
# min                       0.030000               0.010000
# ...
